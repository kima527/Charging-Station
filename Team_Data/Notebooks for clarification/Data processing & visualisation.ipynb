# %% [markdown]
# ---
# ## Model Formulation
#
# ### Sets and Indices
#
# $q \in \text{Q}$: Set of O-D Pair.
#
# $k \in \text{K}$: Set of Potential facility location.
#
# $\text{Q} \in \text{N}_{q}$: Set of nodes capable of capturing the flow $\text{$f$}_{q}$.
#
# $\text{F}_{k}$: Set of flow through node $k$.
#
# -
# ### Parameters
#
# $\text{$f$}_{q}$: Flow volume between O-D pair.
#
# $\text{d}_k $: Statistical, theoretical demand at node $k$.
#
# $\text{FC} $: Fixed station opening cost.
#
# $\text{VC}$: Variable station opening cost.
#
# $\text{B}$: Budget.
#
# $\text{P}$: The number of opening stations.
#
# $\text{M}$: Large number BIG M.
#
#
# -
# ### Decision Variables
#
#
# $\text{x}_{k} $: The number of modules at facility $k$.
#
# $\text{y}_{q} $: Proportion of $\text{$f$}_{q}$ being refueled by station $\text k \in \text{N}_{q}$, considering shared demand at nodes.
#
# $\text{z}_{k} \in \mathbb\{0,1\}$: = 1, if the station is opened at $k$ (0, otherwise).
#
#
#
#
# -
# ### Objective Function
#
# - **Maximize** the total captured flow volume.
#
# \begin{equation}
# \text{Max} \quad Z = \sum_{q \in \text{Q}}
# \text{$f$}_q*\text{y}_{q}
# \tag{0}
# \end{equation}
#
# ### Constraints
#
# - **Module Constraint:**
# \begin{equation}
# \sum_{k \in \text{N}_{q}}\text{x}_{k}/\text{d}_{k} = \text{y}_q \quad \forall (q) \in \text{Q}
# \tag{1}
# \end{equation}
#
# - **Capacity Constraint:**
#
# \begin{equation}
# \sum_{k \in \text{K}}\text{x}_{k}= \text{P}
# \tag{2}
# \end{equation}
#
# - **? Constraint:**
#
# \begin{equation}
# \text{k}_{k} \leq \text{z}_{k} * \text{M}  \quad \forall k \in \text{K}
# \tag{3}
# \end{equation}
#
# - **Budget Constraint:**
#
# \begin{equation}
# \text{z}_{k} * FC + \text{x}_{k} * VC \leq B  \quad \forall k \in \text{K}
# \tag{4}
# \end{equation}
#
# - **Non-negativity Constraint:**
#
# \begin{equation}
# \text{x}_{k} \geq 0  \quad \forall k \in \text{K}
# \tag{5}
# \end{equation}
#
# - **Proportionality Constraint:**
#
# \begin{equation}
# 0 \leq \text{y}_{q} \leq 1    \quad \forall q \in \text{Q}
# \tag{6}
# \end{equation}
#
# - **Binary Constraint:**
#
# \begin{equation}
# \text{z}_{k} \in \mathbb\{0,1\}    \quad \forall k \in \text{K}
# \tag{7}
# \end{equation}

# %%
pip install geopandas osmnx pandas networkx matplotlib geopy
# Out:
# Requirement already satisfied: geopandas in /Users/kima/anaconda3/lib/python3.11/site-packages (0.14.1)
# Requirement already satisfied: osmnx in /Users/kima/anaconda3/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: pandas in /Users/kima/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: networkx in /Users/kima/anaconda3/lib/python3.11/site-packages (3.1)
# Requirement already satisfied: matplotlib in /Users/kima/anaconda3/lib/python3.11/site-packages (3.7.1)
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: fiona>=1.8.21 in /Users/kima/anaconda3/lib/python3.11/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /Users/kima/anaconda3/lib/python3.11/site-packages (from geopandas) (23.0)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/kima/anaconda3/lib/python3.11/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /Users/kima/anaconda3/lib/python3.11/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: numpy>=1.20 in /Users/kima/anaconda3/lib/python3.11/site-packages (from osmnx) (1.24.3)
# Requirement already satisfied: requests>=2.27 in /Users/kima/anaconda3/lib/python3.11/site-packages (from osmnx) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in
# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt

# Define locations
locations = {
    "Marienplatz": "Marienplatz, Munich, Germany",
    "Olympiapark": "Olympiapark, Munich, Germany",
    "HBF": "Hauptbahnhof, Munich, Germany",
    "BMW": "BMW Welt, Munich, Germany",
    "TUM City Center": "Arcisstraße 21, 80333 Munich, Germany",
    "Münchener Freiheit": "Münchener Freiheit, Munich, Germany"
}

def find_nearest_crossing(G, point, min_edges=4, increment=0.0001):
    while True:
        nearest_node = ox.distance.nearest_nodes(G, point[1], point[0], return_dist=False)
        if G.degree[nearest_node] >= min_edges:
            return nearest_node
        else:
            point = (point[0] + increment, point[1] + increment)

# Geocode locations
coords = {name: ox.geocode(loc) for name, loc in locations.items()}

# Create a network graph for Munich
G = ox.graph_from_address("Munich, Germany", network_type='drive', dist=5000)

# Find the nearest crossing nodes to the locations with at least four incident edges
nearest_nodes = {}
for name, point in coords.items():
    nearest_nodes[name] = find_nearest_crossing(G, point, min_edges=4)


# Calculate the shortest paths
routes = [
    nx.shortest_path(G, nearest_nodes["Marienplatz"], nearest_nodes["Olympiapark"], weight='length'),
    nx.shortest_path(G, nearest_nodes["HBF"], nearest_nodes["BMW"], weight='length'),
    nx.shortest_path(G, nearest_nodes["Münchener Freiheit"], nearest_nodes["TUM City Center"], weight='length'),
    nx.shortest_path(G, nearest_nodes["Münchener Freiheit"], nearest_nodes["Olympiapark"], weight='length'),
    nx.shortest_path(G, nearest_nodes["TUM City Center"], nearest_nodes["Marienplatz"], weight='length')
]

# Initialize a list to store the coordinates of all nodes in each route
routes_coords = []

# Define a function to get the coordinates of a node
def get_coords_from_node(graph, node_id):
    node = graph.nodes[node_id]
    return node['y'], node['x']

# Iterate over each route and extract the coordinates of all nodes
for route in routes:
    route_coords = [get_coords_from_node(G, node) for node in route]
    routes_coords.append(route_coords)

# Display the routes with their node coordinates
#for i, route_coords in enumerate(routes_coords, start=1):
#    print(f"Route {i} Coordinates: {route_coords}")

# Plot the graph and routes
fig, ax = ox.plot_graph_routes(G, routes, route_colors=['r', 'b', 'y', 'green', 'skyblue'], route_linewidth=6, node_size=8)
plt.show()

# %% [markdown]
# # Potential Facility Location K Implement

# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
import geopy.distance


# Define locations
locations = {
    "Marienplatz": "Marienplatz, Munich, Germany",
    "Olympiapark": "Olympiapark, Munich, Germany",
    "HBF": "Hauptbahnhof, Munich, Germany",
    "BMW": "BMW Welt, Munich, Germany",
    "TUM City Center": "Arcisstraße 21, 80333 Munich, Germany",
    "Münchener Freiheit": "Münchener Freiheit, Munich, Germany"
}

# Geocode locations
coords = {name: ox.geocode(loc) for name, loc in locations.items()}

# Create a network graph for Munich
G = ox.graph_from_address("Munich, Germany", network_type='drive', dist=4000)

# Find the nearest nodes to the locations
nearest_nodes = {name: ox.distance.nearest_nodes(G, point[1], point[0]) for name, point in coords.items()}

# Calculate the shortest paths
routes = {
    "Marienplatz to Olympiapark": nx.shortest_path(G, nearest_nodes["Marienplatz"], nearest_nodes["Olympiapark"], weight='length'),
    "Olympiapark to HBF": nx.shortest_path(G, nearest_nodes["Olympiapark"], nearest_nodes["HBF"], weight='length'),
    "HBF to BMW": nx.shortest_path(G, nearest_nodes["HBF"], nearest_nodes["BMW"], weight='length'),
    "BMW to TUM City Center": nx.shortest_path(G, nearest_nodes["BMW"], nearest_nodes["TUM City Center"], weight='length'),
    "TUM City Center to Münchener Freiheit": nx.shortest_path(G, nearest_nodes["TUM City Center"], nearest_nodes["Münchener Freiheit"], weight='length'),
    "Münchener Freiheit to Olympiapark": nx.shortest_path(G, nearest_nodes["Münchener Freiheit"], nearest_nodes["Olympiapark"], weight='length'),
}


# Define a function to get the coordinates of a node
def get_coords_from_node(graph, node_id):
    node = graph.nodes[node_id]
    return node['y'], node['x']

# Iterate over each route and extract the coordinates of all nodes
routes_coords = {}
for route_name, route in routes.items():
    route_coords = [Point(G.nodes[node]['x'], G.nodes[node]['y']) for node in route]
    routes_coords[route_name] = LineString(route_coords)

# Fetch parking data for Munich
parking = ox.features_from_place("Munich, Germany", tags={'amenity': 'parking'})
print(f"Total parking lots: {len(parking)}")

# Function to check if a parking lot is within 1km of any route
def is_parking_near_any_route(parking_point, routes_coords):
    for route_line in routes_coords.values():
        # Use geopy to calculate distance
        nearest_point = route_line.interpolate(route_line.project(parking_point))
        distance = geopy.distance.distance((parking_point.y, parking_point.x), (nearest_point.y, nearest_point.x)).km
        if distance < 0.5:  # 1 km
            return True
    return False


filtered_parking = parking[parking.apply(lambda x: is_parking_near_any_route(x.geometry.centroid, routes_coords), axis=1)]
print(f"Filtered parking lots: {len(filtered_parking)}")  # Print filtered parking lots


# Get the coordinates of filtered parking lots
filtered_parking_coordinates = [(p.geometry.centroid.y, p.geometry.centroid.x) for p in filtered_parking.itertuples()]

# Extract the route lists from the routes dictionary for plotting
route_lists = list(routes.values())



# Ensure that route_colors has the same number of elements as route_lists
route_colors = ['orange', 'b', 'purple', 'green', 'skyblue', 'pink'] * (len(route_lists) // 5 + 1)
route_colors = route_colors[:len(route_lists)]  # Trim the list to the length of route_lists

# Plot the graph and routes
fig, ax = ox.plot_graph_routes(G, route_lists, route_colors=route_colors, route_linewidth=6, node_size=50, figsize=(12, 12), show=False, close=False)

# Plot filtered parking lots
for y, x in filtered_parking_coordinates:
    ax.scatter(x, y, c='red', s=30, alpha=0.7, zorder=5)  # Increase the size for visibility    


plt.show()
#print(filtered_parking_coordinates)
# Out:
# Total parking lots: 5050
# Filtered parking lots: 336

# %% [markdown]
# ## Feed the data into the model

# %%
import gurobipy as gp
from gurobipy import GRB

# OD-pairs based on your routes
Q = list(routes.keys())  # OD-pairs as strings

K = set()
for route in routes.values():
    K.update(route)
K = list(K)

# Nodes capable of capturing the flow of OD-pair q
N_q = {od: routes[od] for od in Q}

# Flows through OD-pairs - Define based on your scenario
f_q = {od: flow_value for od, flow_value in zip(Q, [8, 2, 4, 6, 5, 3])}  # Example flows

# Initialize d_k with zeros for all nodes
d_k = {node: 0 for node in G.nodes()}

# Iterate over each OD pair and its route
for od, route in routes.items():
    flow = f_q[od]  # Flow for the current OD pair
    for node in route:
        d_k[node] += flow  # Add the flow to the demand of the node

for od, route in N_q.items():
    print(f"OD Pair '{od}' with flow {f_q[od]}:")
    for node in route:
        print(f"  Node {node} has demand {d_k[node]}")
        
# d_k now contains the summed demand for each node based on the routes and flows

FC = 20  # Fixed charging station installation cost
VC = 5   # Variable charging station installation cost
B = 100  # Budget
CAP = 8  # Module Cap
M = 999999  # Very large number

# Create a Gurobi model
model = gp.Model("OD_Flow_Maximization")

# Decision variables
y = model.addVars(Q, lb=0.0, ub=1.0, vtype=GRB.CONTINUOUS, name="y")
x = model.addVars(K, lb=0, vtype=GRB.INTEGER, name="x")
z = model.addVars(K, vtype=GRB.BINARY, name="z")

# Objective function
model.setObjective(gp.quicksum(f_q[od] * y[od] for od in Q), GRB.MAXIMIZE)

# Constraints
model.addConstrs((gp.quicksum(x[k] / d_k[k] for k in N_q[od]) >= y[od] for od in Q), "Proportion_Refueled")
model.addConstr(gp.quicksum(z[k] * FC + x[k] * VC for k in K) <= B, "Budget_Constraint")
model.addConstrs((x[k] <= z[k] * M for k in K), "Module_Capacity")
model.addConstrs((x[k] <= CAP for k in K), "Cap on modules at one station")

# Solve the optimization problem
model.optimize()

# Print the results
if model.status == GRB.OPTIMAL:
    print("Optimal Objective Value:", model.objVal)
    print("Optimal Solution:")
    for od in Q:
        print(f"y_{od}:", y[od].x)
    for k in K:
        print(f"x_{k}:", x[k].x)
        print(f"z_{k}:", z[k].x)
else:
    print("Optimization problem did not converge to an optimal solution.")
# Out:
# OD Pair 'Marienplatz to Olympiapark' with flow 8:
#   Node 342246643 has demand 8
#   Node 1313365838 has demand 8
#   Node 1313365829 has demand 8
#   Node 18926931 has demand 8
#   Node 32053498 has demand 8
#   Node 18931611 has demand 8
#   Node 18931608 has demand 8
#   Node 361798 has demand 8
#   Node 185840092 has demand 8
#   Node 1109379997 has demand 8
#   Node 18931002 has demand 8
#   Node 18929527 has demand 8
#   Node 18291200 has demand 8
#   Node 361793 has demand 8
#   Node 361792 has demand 8
#   Node 21005407 has demand 8
#   Node 331133382 has demand 8
#   Node 1240291609 has demand 8
#   Node 1240291611 has demand 8
#   Node 361775 has demand 8
#   Node 361776 has demand 8
#   Node 21642943 has demand 8
#   Node 3571467212 has demand 8
#   Node 21026888 has demand 8
#   Node 20981716 has demand 8
#   Node 361779 has demand 8
#   Node 361780 has demand 8
#   Node 1241343853 has demand 8
#   Node 18291522 has demand 8
#   Node 20980558 has demand 8
#   Node 361791 has demand 12
#   Node 361790 has demand 12
#   Node 361802 has demand 12
#   Node 361803 has demand 8
#   Node 20980542 has demand 10
#   Node 25576845 has demand 10
#   Node 6730042 has demand 10
#   Node 1955536 has demand 10
#   Node 679217451 has demand 10
#   Node 679217457 has demand 10
#   Node 1692554982 has demand 10
#   Node 16527604 has demand 10
#   Node 21035972 has demand 8
#   Node 21035975 has demand 8
#   Node 16259352 has demand 8
#   Node 16259330 has demand 8
#   Node 21035977 has demand 13
#   Node 246790116 has demand 13
# OD Pair 'Olympiapark to HBF' with flow 2:
#   Node 246790116 has demand 13
#   Node 21035977 has demand 13
#   Node 16527735 has demand 2
#   Node 21035971 has demand 2
#   Node 266740994 has demand 2
#   Node 16527604 has demand 10
#   Node 1692554982 has demand 10
#   Node 679217457 has demand 10
#   Node 679217451 has demand 10
#   Node 1955536 has demand 10
#   Node 6730042 has demand 10
#   Node 25576845 has demand 10
#   Node 20980542 has demand 10
#   Node 363206 has demand 2
#   Node 20980544 has demand 2
#   Node 20980545 has demand 2
#   Node 20980546 has demand 2
#   Node 20980553 has demand 2
#   Node 20980554 has demand 2
#   Node 1012031604 has demand 2
#   Node 20980561 has demand 2
#   Node 21026892 has demand 2
#   Node 20981711 has demand 2
#   Node 21324003 has demand 2
#   Node 20981713 has demand 2
#   Node 1956101 has demand 6
# OD Pair 'HBF to BMW' with flow 4:
#   Node 1956101 has demand 6
#   Node 21324004 has demand 4
#   Node 1141315726 has demand 4
#   Node 1710336183 has demand 4
#   Node 361786 has demand 4
#   Node 21026891 has demand 4
#   Node 13883943 has demand 4
#   Node 1028580806 has demand 4
#   Node 361791 has demand 12
#   Node 361790 has demand 12
#   Node 361802 has demand 12
#   Node 1955531 has demand 4
#   Node 246879849 has demand 4
#   Node 1955498 has demand 4
#   Node 1972874111 has demand 4
#   Node 6730035 has demand 4
#   Node 25576849 has demand 4
#   Node 1843938668 has demand 4
#   Node 25576847 has demand 4
#   Node 967126093 has demand 4
#   Node 967126079 has demand 4
#   Node 271153621 has demand 4
#   Node 16527601 has demand 4
#   Node 1955540 has demand 4
#   Node 27733777 has demand 4
#   Node 16527632 has demand 4
#   Node 16527634 has demand 10
#   Node 16527631 has demand 10
#   Node 16527629 has demand 10
#   Node 8264853485 has demand 10
#   Node 8264853486 has demand 13
#   Node 16527736 has demand 10
#   Node 16527739 has demand 10
# OD Pair 'BMW to TUM City Center' with flow 6:
#   Node 16527739 has demand 10
#   Node 16527736 has demand 10
#   Node 8264853486 has demand 13
#   Node 8264853485 has demand 10
#   Node 16527629 has demand 10
#   Node 16527631 has demand 10
#   Node 16527634 has demand 10
#   Node 16527635 has demand 6
#   Node 21042662 has demand 6
#   Node 28092175 has demand 6
#   Node 27487412 has demand 6
#   Node 28092174 has demand 6
#   Node 1955529 has demand 6
#   Node 1562831797 has demand 6
#   Node 27735976 has demand 6
#   Node 1955527 has demand 6
#   Node 21090905 has demand 6
#   Node 8867266359 has demand 6
#   Node 1955512 has demand 6
#   Node 21090904 has demand 6
#   Node 27161285 has demand 6
#   Node 1955505 has demand 6
#   Node 1955504 has demand 6
#   Node 1955535 has demand 6
#   Node 8748896852 has demand 6
#   Node 20835174 has demand 6
#   Node 1955500 has demand 11
#   Node 7983343 has demand 11
#   Node 315667013 has demand 11
#   Node 345553442 has demand 11
#   Node 21457468 has demand 11
# OD Pair 'TUM City Center to Münchener Freiheit' with flow 5:
#   Node 21457468 has demand 11
#   Node 345553442 has demand 11
#   Node 315667013 has demand 11
#   Node 7983343 has demand 11
#   Node 1955500 has demand 11
#   Node 922831072 has demand 5
#   Node 27487423 has demand 5
#   Node 258890820 has demand 5
#   Node 27487425 has demand 5
#   Node 1954309 has demand 5
#   Node 1955506 has demand 5
#   Node 1955508 has demand 5
#   Node 639992773 has demand 5
#   Node 1954434 has demand 5
#   Node 374110738 has demand 5
#   Node 1955518 has demand 5
#   Node 1954313 has demand 5
#   Node 27487419 has demand 5
#   Node 1954316 has demand 5
#   Node 2481363135 has demand 5
#   Node 27479770 has demand 5
#   Node 2329213041 has demand 5
#   Node 27479836 has demand 5
#   Node 27744798 has demand 5
#   Node 28092164 has demand 5
#   Node 27744793 has demand 5
#   Node 4738778742 has demand 5
#   Node 13883760 has demand 5
#   Node 36717053 has demand 5
#   Node 36717035 has demand 5
#   Node 36717026 has demand 8
#   Node 1955583 has demand 8
#   Node 21092018 has demand 8
#   Node 54788228 has demand 8
#   Node 54788219 has demand 8
#   Node 54792795 has demand 8
# OD Pair 'Münchener Freiheit to Olympiapark' with flow 3:
#   Node 54792795 has demand 8
#   Node 54788219 has demand 8
#   Node 54788228 has demand 8
#   Node 21092018 has demand 8
#   Node 1955583 has demand 8
#   Node 36717026 has demand 8
#   Node 36717019 has demand 3
#   Node 1955573 has demand 3
#   Node 27006682 has demand 3
#   Node 25313840 has demand 3
#   Node 262699038 has demand 3
#   Node 38152435 has demand 3
#   Node 38156718 has demand 3
#   Node 3685462394 has demand 3
#   Node 3685462395 has demand 3
#   Node 3423591692 has demand 3
#   Node 21091226 has demand 3
#   Node 204257758 has demand 3
#   Node 38162316 has demand 3
#   Node 1955561 has demand 3
#   Node 4611877354 has demand 3
#   Node 21036248 has demand 3
#   Node 1117390122 has demand 3
#   Node 267162988 has demand 3
#   Node 8264853486 has demand 13
#   Node 21036247 has demand 3
#   Node 16527673 has demand 3
#   Node 16527636 has demand 3
#   Node 21035981 has demand 3
#   Node 21035977 has demand 13
#   Node 246790116 has demand 13
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 347 rows, 346 columns and 1061 nonzeros
# Model fingerprint: 0x14dfd0c7
# Variable types: 6 continuous, 340 integer (170 binary)
# Coefficient statistics:
#   Matrix range     [8e-02, 1e+06]
#   Objective range  [2e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e+00, 1e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 170 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 177 rows, 346 columns, 891 nonzeros
# Variable types: 2 continuous, 344 integer (170 binary)
#
# Root relaxation: objective 1.333333e+01, 213 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   13.33333    0    2   -0.00000   13.33333      -     -    0s
# H    0     0                      11.4666667   13.33333  16.3%     -    0s
# H    0     0                      12.0000000   13.33333  11.1%     -    0s
#      0     0   13.33333    0   10   12.00000   13.33333  11.1%     -    0s
#      0     0   13.33333    0